# %% [markdown]
# # <font color="orange"> **DATA PREPARATION** </font>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('data.csv')

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
df.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
df.drop(columns=['Unnamed: 32'], inplace=True)

# %%
df.duplicated(subset=['id'])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 564    False
# 565    False
# 566    False
# 567    False
# 568    False
# Length: 569, dtype: bool

# %%
df['diagnosis'].nunique()
# Out:
# 2

# %%
df['diagnosis'] = df['diagnosis'].map({'M': 1, 'B': 0})

# %%
df.head()
# Out:
#          id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302          1        17.99         10.38          122.80     1001.0
# 1    842517          1        20.57         17.77          132.90     1326.0
# 2  84300903          1        19.69         21.25          130.00     1203.0
# 3  84348301          1        11.42         20.38           77.58      386.1
# 4  84358402          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.drop(columns=['id'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   diagnosis                569 non-null    int64
#  1   radius_mean              569 non-null    float64
#  2   texture_mean             569 non-null    float64
#  3   perimeter_mean           569 non-null    float64
#  4   area_mean                569 non-null    float64
#  5   smoothness_mean          569 non-null    float64
#  6   compactness_mean         569 non-null    float64
#  7   concavity_mean           569 non-null    float64
#  8   concave points_mean      569 non-null    float64
#  9   symmetry_mean            569 non-null    float64
#  10  fractal_dimension_mean   569 non-null    float64
#  11  radius_se                569 non-null    float64
#  12  texture_se               569 non-null    float64
# ...

# %%
figure, axes = plt.subplots(5, 6, figsize=(20, 15))

axes[0,0].scatter(df['radius_mean'], df['diagnosis'])
axes[0,0].set_title('radius_mean vs diagnosis')
axes[0,0].set_xlabel('radius_mean')
axes[0,0].set_ylabel('diagnosis')

axes[0,1].scatter(df['texture_mean'], df['diagnosis'])
axes[0,1].set_title('texture_mean vs diagnosis')
axes[0,1].set_xlabel('texture_mean')
axes[0,1].set_ylabel('diagnosis')

axes[0,2].scatter(df['perimeter_mean'], df['diagnosis'])
axes[0,2].set_title('perimeter_mean vs diagnosis')
axes[0,2].set_xlabel('perimeter_mean')
axes[0,2].set_ylabel('diagnosis')

axes[0,3].scatter(df['area_mean'], df['diagnosis'])
axes[0,3].set_title('area_mean vs diagnosis')
axes[0,3].set_xlabel('area_mean')
axes[0,3].set_ylabel('diagnosis')

axes[0,4].scatter(df['smoothness_mean'], df['diagnosis'])
axes[0,4].set_title('smoothness_mean vs diagnosis')
axes[0,4].set_xlabel('smoothness_mean')
axes[0,4].set_ylabel('diagnosis')

axes[0,5].scatter(df['compactness_mean'], df['diagnosis'])
axes[0,5].set_title('compactness_mean vs diagnosis')
axes[0,5].set_xlabel('compactness_mean')
axes[0,5].set_ylabel('diagnosis')


axes[1,0].scatter(df['concavity_mean'], df['diagnosis'])
axes[1,0].set_title('concavity_mean vs diagnosis')
axes[1,0].set_xlabel('concavity_mean')
axes[1,0].set_ylabel('diagnosis')

axes[1,1].scatter(df['concave points_mean'], df['diagnosis'])
axes[1,1].set_title('concave points_mean vs diagnosis')
axes[1,1].set_xlabel('concave points_mean')
axes[1,1].set_ylabel('diagnosis')

axes[1,2].scatter(df['symmetry_mean'], df['diagnosis'])
axes[1,2].set_title('symmetry_mean vs diagnosis')
axes[1,2].set_xlabel('symmetry_mean')
axes[1,2].set_ylabel('diagnosis')

axes[1,3].scatter(df['fractal_dimension_mean'], df['diagnosis'])
axes[1,3].set_title('fractal_dimension_mean vs diagnosis')
axes[1,3].set_xlabel('fractal_dimension_mean')
axes[1,3].set_ylabel('diagnosis')

axes[1,4].scatter(df['radius_se'], df['diagnosis'])
axes[1,4].set_title('radius_se vs diagnosis')
axes[1,4].set_xlabel('radius_se')
axes[1,4].set_ylabel('diagnosis')

axes[1,5].scatter(df['texture_se'], df['diagnosis'])
axes[1,5].set_title('texture_se vs diagnosis')
axes[1,5].set_xlabel('texture_se')
axes[1,5].set_ylabel('diagnosis')


axes[2,0].scatter(df['perimeter_se'], df['diagnosis'])
axes[2,0].set_title('perimeter_se vs diagnosis')
axes[2,0].set_xlabel('perimeter_se')
axes[2,0].set_ylabel('diagnosis')

axes[2,1].scatter(df['area_se'], df['diagnosis'])
axes[2,1].set_title('area_se vs diagnosis')
axes[2,1].set_xlabel('area_se')
axes[2,1].set_ylabel('diagnosis')

axes[2,2].scatter(df['smoothness_se'], df['diagnosis'])
axes[2,2].set_title('smoothness_se vs diagnosis')
axes[2,2].set_xlabel('smoothness_se')
axes[2,2].set_ylabel('diagnosis')

axes[2,3].scatter(df['compactness_se'], df['diagnosis'])
axes[2,3].set_title('compactness_se vs diagnosis')
axes[2,3].set_xlabel('compactness_se')
axes[2,3].set_ylabel('diagnosis')

axes[2,4].scatter(df['concavity_se'], df['diagnosis'])
axes[2,4].set_title('concavity_se vs diagnosis')
axes[2,4].set_xlabel('concavity_se')
axes[2,4].set_ylabel('diagnosis')

axes[2,5].scatter(df['concave points_se'], df['diagnosis'])
axes[2,5].set_title('concave points_se vs diagnosis')
axes[2,5].set_xlabel('concave points_se')
axes[2,5].set_ylabel('diagnosis')


axes[3,0].scatter(df['symmetry_se'], df['diagnosis'])
axes[3,0].set_title('symmetry_se vs diagnosis')
axes[3,0].set_xlabel('symmetry_se')
axes[3,0].set_ylabel('diagnosis')

axes[3,1].scatter(df['fractal_dimension_se'], df['diagnosis'])
axes[3,1].set_title('fractal_dimension_se vs diagnosis')
axes[3,1].set_xlabel('fractal_dimension_se')
axes[3,1].set_ylabel('diagnosis')

axes[3,2].scatter(df['radius_worst'], df['diagnosis'])
axes[3,2].set_title('radius_worst vs diagnosis')
axes[3,2].set_xlabel('radius_worst')
axes[3,2].set_ylabel('diagnosis')

axes[3,3].scatter(df['texture_worst'], df['diagnosis'])
axes[3,3].set_title('texture_worst vs diagnosis')
axes[3,3].set_xlabel('texture_worst')
axes[3,3].set_ylabel('diagnosis')

axes[3,4].scatter(df['perimeter_worst'], df['diagnosis'])
axes[3,4].set_title('perimeter_worst vs diagnosis')
axes[3,4].set_xlabel('perimeter_worst')
axes[3,4].set_ylabel('diagnosis')

axes[3,5].scatter(df['area_worst'], df['diagnosis'])
axes[3,5].set_title('area_worst vs diagnosis')
axes[3,5].set_xlabel('area_worst')
axes[3,5].set_ylabel('diagnosis')


axes[4,0].scatter(df['smoothness_worst'], df['diagnosis'])
axes[4,0].set_title('smoothness_worst vs diagnosis')
axes[4,0].set_xlabel('smoothness_worst')
axes[4,0].set_ylabel('diagnosis')

axes[4,1].scatter(df['compactness_worst'], df['diagnosis'])
axes[4,1].set_title('compactness_worst vs diagnosis')
axes[4,1].set_xlabel('compactness_worst')
axes[4,1].set_ylabel('diagnosis')

axes[4,2].scatter(df['concavity_worst'], df['diagnosis'])
axes[4,2].set_title('concavity_worst vs diagnosis')
axes[4,2].set_xlabel('concavity_worst')
axes[4,2].set_ylabel('diagnosis')

axes[4,3].scatter(df['concave points_worst'], df['diagnosis'])
axes[4,3].set_title('concave points_worst vs diagnosis')
axes[4,3].set_xlabel('concave points_worst')
axes[4,3].set_ylabel('diagnosis')

axes[4,4].scatter(df['symmetry_worst'], df['diagnosis'])
axes[4,4].set_title('symmetry_worst vs diagnosis')
axes[4,4].set_xlabel('symmetry_worst')
axes[4,4].set_ylabel('diagnosis')

axes[4,5].scatter(df['fractal_dimension_worst'], df['diagnosis'])
axes[4,5].set_title('fractal_dimension_worst vs diagnosis')
axes[4,5].set_xlabel('fractal_dimension_worst')
axes[4,5].set_ylabel('diagnosis')

plt.tight_layout()
plt.show()

# %% [markdown]
# # <font color="orange"> **MODEL** </font>

# %% [markdown]
# ### **Sigmoid Function**
# $$f_{\vec{w},b}(\vec{x}) = g(z) = \frac{1}{1 + e^{-z}}$$
# $$\text{where } z = \vec{w} \cdot \vec{x} + b$$

# %%
x_train = df[[
    'radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'smoothness_mean',
    'compactness_mean', 'concavity_mean', 'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
    'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
    'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se', 'fractal_dimension_se',
    'radius_worst', 'texture_worst', 'perimeter_worst', 'area_worst', 'smoothness_worst',
    'compactness_worst', 'concavity_worst', 'concave points_worst', 'symmetry_worst', 'fractal_dimension_worst'
]].to_numpy()
y_train=df['diagnosis'].to_numpy()

# %%
mu = x_train.mean(axis=0)
sigma = x_train.std(axis=0)
x_train = (x_train - mu) / sigma

# %% [markdown]
# ### **Cost Function**
# $$J(\vec{w},b) = -\frac{1}{m} \sum_{i=1}^{m} \left[ y^{(i)} \log \left( f_{\vec{w},b}(\vec{x}^{(i)}) \right) + (1 - y^{(i)}) \log \left( 1 - f_{\vec{w},b}(\vec{x}^{(i)}) \right) \right]$$

# %%
def cost(x,y,w,b):
  m=x.shape[0]
  cost=0
  z=np.dot(x,w)+b
  f_wb=1/(1+np.exp(-z))
  for i in range (m):
    cost=cost+((y[i]*np.log(f_wb[i]))+((1-y[i])*np.log(1-f_wb[i])))
  return cost/(-m)

# %% [markdown]
# ###**Partial Derivatives**
# $$\begin{align*}
# \frac{\partial}{\partial w_j} J(\vec{w},b) &= \frac{1}{m} \sum_{i=1}^{m} \left( f_{\vec{w},b}(\vec{x}^{(i)}) - y^{(i)} \right) x_j^{(i)} \\
# \frac{\partial}{\partial b} J(\vec{w},b) &= \frac{1}{m} \sum_{i=1}^{m} \left( f_{\vec{w},b}(\vec{x}^{(i)}) - y^{(i)} \right)
# \end{align*}$$

# %%
def dj_dw(x,y,w,b):
  m=x.shape[0]
  z=np.dot(x,w)+b
  f_wb=1/(1+np.exp(-z))
  dj_dw=0
  for i in range(m):
    dj_dw=dj_dw+(f_wb[i]-y[i])*x[i]
  return dj_dw/m

def dj_db(x,y,w,b):
    m=x.shape[0]
    z=np.dot(x,w)+b
    f_wb=1/(1+np.exp(-z))
    dj_db=0
    for i in range(m):
      dj_db=dj_db+(f_wb[i]-y[i])
    return dj_db/m

# %% [markdown]
# ### **Gradient Descent**
# $$\begin{align*}
# &\text{repeat \{} \\
# & w_j = w_j - \alpha \frac{\partial}{\partial w_j} J(\vec{w},b) \\
# & b = b - \alpha \frac{\partial}{\partial b} J(\vec{w},b) \\
# &\text{\} simultaneous updates}
# \end{align*}$$

# %%
def gradient_descent(alpha):
  w=0
  b=0
  for i in range(1000):
    w=w-(alpha*dj_dw(x_train,y_train,w,b))
    b=b-(alpha*dj_db(x_train,y_train,w,b))
  return w,b

# %%
gradient_descent(0.1)
# Out:
# (array([ 0.55701096,  0.62986075,  0.54044949,  0.58689076,  0.23090541,
#         -0.12575798,  0.60743832,  0.71760687,  0.06293833, -0.40069971,
#          0.86335414, -0.0808405 ,  0.63118713,  0.69743255,  0.14069066,
#         -0.55847568, -0.07750363,  0.15979743, -0.2451882 , -0.51126852,
#          0.8511439 ,  0.95077659,  0.77139882,  0.81763497,  0.75020644,
#          0.14708685,  0.67012725,  0.81597876,  0.68752897,  0.2067733 ]),
#  np.float64(-0.44418002817090213))
